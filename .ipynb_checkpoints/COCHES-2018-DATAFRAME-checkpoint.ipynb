# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
compradores = (50, 20, 80, 40)
coches = ('Audi', 'Ford', 'Seat', 'Mercedes')
plt.plot(compradores)
plt.title("demanda de vehiculos en 2018")
plt.xlabel("2018")
plt.savefig ('coches_dataframes.pdf')
